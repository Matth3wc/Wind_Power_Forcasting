# %%
import sys
sys.path.append('../src')
from irish_buoy_data import IrishBuoyData

# Test the IrishBuoyData class
buoy = IrishBuoyData(station_id="M5")

# Fetch data (default 30 days)
data = buoy.fetch_data(days_back=5000)


# Print basic info
print("Full Dataset:")
print(data.head())
print(f"\nShape: {data.shape}")
print(f"\nColumns: {data.columns.tolist()}")

# Test baseline subset (meteorological only)
baseline = buoy.get_baseline_subset(data)
print("\n--- Baseline Subset (Met features only) ---")
print(baseline.head())
print(f"Columns: {baseline.columns.tolist()}")

# Test wave-enhanced subset
wave_enhanced = buoy.get_wave_enhanced_subset(data)
print("\n--- Wave-Enhanced Subset ---")
print(wave_enhanced.head())
print(f"Columns: {wave_enhanced.columns.tolist()}")

# Check for missing values
print(f"\n--- Data Quality ---")
print(f"Total rows: {len(data)}")
print(f"Date range: {data.index.min()} to {data.index.max()}")
print(f"\nMissing values per column:")
print(data.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_transports/default.py:127, in ResponseStream.__iter__(self)
#     126 with map_httpcore_exceptions():
# --> 127     for part in self._httpcore_stream:
#     128         yield part
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     406 self.close()
# --> 407 raise exc from None
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     402 try:
# --> 403     for part in self._stream:
#     404         yield part
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     341     self.close()
# --> 342 raise exc
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     333 with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334     for chunk in self._connection._receive_response_body(**kwargs):
#     335         yield chunk
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[1], line 9
#       6 buoy = IrishBuoyData(station_id="M5")
#       8 # Fetch data (default 30 days)
# ----> 9 data = buoy.fetch_data(days_back=5000)
#      12 # Print basic info
#      13 print("Full Dataset:")
#
# File ~/Documents/GitHub/Wind_Power_Forcasting/notebooks/../src/irish_buoy_data.py:35, in IrishBuoyData.fetch_data(self, days_back)
#      28 self.e.variables = ["time", "station_id", "WindSpeed", "AirTemperature",
#      29                    "AtmosphericPressure", "WaveHeight", "Hmax", "Tp"]
#      30 self.e.constraints = {
#      31     "time>=": f"now-{days_back}days",
#      32     "station_id=": self.station_id,
#      33 }
# ---> 35 df = self.e.to_pandas(index_col="time (UTC)", parse_dates=True)
#      36 return df.dropna()
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/erddapy/erddapy.py:420, in ERDDAP.to_pandas(self, requests_kwargs, **kw)
#     418 distinct = kw.pop("distinct", False)
#     419 url = self.get_download_url(response=response, distinct=distinct)
# --> 420 return to_pandas(
#     421     url,
#     422     requests_kwargs=requests_kwargs,
#     423     pandas_kwargs={**kw},
#     424 )
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/erddapy/core/interfaces.py:37, in to_pandas(url, requests_kwargs, pandas_kwargs)
#      26 def to_pandas(
#      27     url: str,
#      28     requests_kwargs: dict | None = None,
#      29     pandas_kwargs: dict | None = None,
#      30 ) -> pd.DataFrame:
#      31     """Convert a URL to Pandas DataFrame.
#      32
#      33     url: URL to request data from.
#      34     requests_kwargs: arguments to be passed to urlopen method.
#      35     **pandas_kwargs: kwargs to be passed to third-party library (pandas).
#      36     """
# ---> 37     data = urlopen(url, requests_kwargs or {})
#      38     try:
#      39         return pd.read_csv(data, **(pandas_kwargs or {}))
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/erddapy/core/url.py:101, in urlopen(url, requests_kwargs)
#      99 if requests_kwargs is None:
#     100     requests_kwargs = {}
# --> 101 data = _urlopen(url, **requests_kwargs)
#     102 data.seek(0)
#     103 return data
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/erddapy/core/url.py:64, in _urlopen(url, auth, **kwargs)
#      62 if "timeout" not in kwargs:
#      63     kwargs["timeout"] = 60
# ---> 64 response = httpx.get(
#      65     quote_url(url),
#      66     follow_redirects=True,
#      67     auth=auth,
#      68     **kwargs,
#      69 )
#      70 try:
#      71     response.raise_for_status()
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_api.py:195, in get(url, params, headers, cookies, auth, proxy, follow_redirects, verify, timeout, trust_env)
#     174 def get(
#     175     url: URL | str,
#     176     *,
#    (...)
#     185     trust_env: bool = True,
#     186 ) -> Response:
#     187     """
#     188     Sends a `GET` request.
#     189
#    (...)
#     193     on this function, as `GET` requests should not include a request body.
#     194     """
# --> 195     return request(
#     196         "GET",
#     197         url,
#     198         params=params,
#     199         headers=headers,
#     200         cookies=cookies,
#     201         auth=auth,
#     202         proxy=proxy,
#     203         follow_redirects=follow_redirects,
#     204         verify=verify,
#     205         timeout=timeout,
#     206         trust_env=trust_env,
#     207     )
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_api.py:109, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxy, timeout, follow_redirects, verify, trust_env)
#      57 """
#      58 Sends an HTTP request.
#      59
#    (...)
#     100 ```
#     101 """
#     102 with Client(
#     103     cookies=cookies,
#     104     proxy=proxy,
#    (...)
#     107     trust_env=trust_env,
#     108 ) as client:
# --> 109     return client.request(
#     110         method=method,
#     111         url=url,
#     112         content=content,
#     113         data=data,
#     114         files=files,
#     115         json=json,
#     116         params=params,
#     117         headers=headers,
#     118         auth=auth,
#     119         follow_redirects=follow_redirects,
#     120     )
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_transports/default.py:126, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
# --> 126     with map_httpcore_exceptions():
#     127         for part in self._httpcore_stream:
#     128             yield part
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File /opt/anaconda3/envs/streamlit_env/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
